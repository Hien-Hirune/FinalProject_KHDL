# %%
# !which python
# Out:
# /home/wangling/miniconda3/envs/p4ds-env/bin/python

# %%
#!conda install -y seaborn plotly

# %% [markdown]
# # Final project: Phân tích dữ liệu Data Engineer Jobs
# Các thành viên:
#
# 1. Phạm Thị Hoài Hiền - 18120178
#
# 2. Vương Thị Ngọc Linh - 18120195

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import re 
import plotly.express as px

# %%
#plt.style.use('seaborn')

# %% [markdown]
# ## Giới thiệu về dữ liệu
#
# Đây là bộ dữ liệu về việc làm Data Engineer và một số vị trí liên quan, link Kaggle lấy dữ liệu: https://www.kaggle.com/andrewmvd/data-engineer-jobs
#
# Datatset này được tạo bởi Picklesueat và nó chứa hơn 2500 công việc liên quan vị trí Data Engineer.
#
# Dataset gồm có 15 cột:
# - Job Tile: Tên vị trí
# - Salary Estimate: Mức lương
# - Job Description: Miêu tả vị trí
# - Rating: Xếp hạng công ty tuyển dụng
# - Company name: Tên công ty tuyển dụng
# - Location: Địa chỉ nơi làm việc
# - Headquarters: Trụ sở của công ty
# - Size: Quy mô nhân lực của công ty
# - Founded: Năm thành lập công ty
# - Type of ownership: Quyền sở hữu
# - Industry: Lĩnh vực hoạt động của công ty
# - Sector: Lĩnh vực chuyên ngành mà công ty phát triển.
# - Revenue: Doanh thu mỗi năm của công ty.
# - Competitors: Đối thủ cạnh tranh của công ty.
# - Easy Apply: Vị trí này có dễ apply không.

# %% [markdown]
# ## Tiền xử lí

# %% [markdown]
# ### Đọc dữ liệu vào dataframe

# %%
data_engineer_jobs = pd.read_csv("DataEngineer.csv")
data_engineer_jobs.shape
# Out:
# (2528, 15)

# %%
data_engineer_jobs
# Out:
#                                               Job Title  \
# 0                                         Data Engineer
# 1     Senior Data Engineer (Healthcare Domain experi...
# 2                                        Data Engineers
# 3                         Client Trade Support Engineer
# 4                                         Data Engineer
# ...                                                 ...
# 2523                                     Cloud Engineer
# 2524                                Electrical Engineer
# 2525                              Sr. Big Data Engineer
# 2526                     Senior Big Data / ETL Engineer
# 2527                                     Cloud Engineer
#
#                   Salary Estimate  \
# 0     $80K-$150K (Glassdoor est.)
# 1     $80K-$150K (Glassdoor est.)
# 2     $80K-$150K (Glassdoor est.)
# 3     $80K-$150K (Glassdoor est.)
# 4     $80K-$150K (Glassdoor est.)
# ...                           ...
# 2523  $76K-$128K (Glassdoor est.)
# 2524  $76K-$128K (Glassdoor est.)
# 2525  $76K-$128K (Glassdoor est.)
# 2526  $76K-$128K (Glassdoor est.)
# 2527  $76K-$128K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Company Description\nSagence is a management a...     4.5
# 1     Key Responsibilities\n\n- Architect, build, an...     3.4
# 2     Overview\n\nJob description\n\nPosition Overvi...     5.0
# 3     About the Position\n\n\nThis position will sup...     4.8
# 4     Data Engineer\n\nJob Details\nLevel\nExperienc...     3.7
# ...                                                 ...     ...
# 2523  The Expertise You Have Proven expertise in dev...     4.5
# 2524  Lockheed Martin is seeking a Circuit and FPGA ...     2.9
# 2525  Posting Title Principal Data Engineer (Contrac...     3.7
# 2526  Your Opportunity\n\nCharles Schwab & Co., Inc ...     3.5
# 2527  Cloud Engineer Westlake, TX 6+ months Descript...     3.6
#
#                                    Company Name        Location  \
# 0                                  Sagence\n4.5    New York, NY
# 1                   Enterprise Integration\n3.4    New York, NY
# 2                     Maestro Technologies\n5.0    New York, NY
# 3                              Jane Street\n4.8    New York, NY
# 4                  GNY Insurance Companies\n3.7    New York, NY
# ...                                         ...             ...
# 2523                            PMG Global\n4.5    Westlake, TX
# 2524            Albin Engineering Services\n2.9  Fort Worth, TX
# 2525  Cincinnati Bell Technology Solutions\n3.7      Irving, TX
# 2526                                Schwab\n3.5    Westlake, TX
# 2527        SPECTRAFORCE TECHNOLOGIES Inc.\n3.6    Westlake, TX
#
#              Headquarters                   Size  Founded  Type of ownership  \
# 0             Chicago, IL      1 to 50 employees     2009  Company - Private
# 1        Jacksonville, FL    51 to 200 employees     1998  Company - Private
# 2             Trenton, NJ    51 to 200 employees     2003  Company - Private
# 3            New York, NY  501 to 1000 employees     2000  Company - Private
# 4            New York, NY   201 to 500 employees     1914  Company - Private
# ...                   ...                    ...      ...                ...
# 2523          Herndon, VA      1 to 50 employees       -1  Company - Private
# 2524      Santa Clara, CA    51 to 200 employees     1993  Company - Private
# 2525       Cincinnati, OH  501 to 1000 employees       -1  Company - Private
# 2526  Dettenheim, Germany                Unknown       -1   Company - Public
# 2527          Raleigh, NC  501 to 1000 employees     2000  Company - Private
#
#                                    Industry                  Sector  \
# 0                                Consulting       Business Services
# 1                               IT Services  Information Technology
# 2                               IT Services  Information Technology
# 3     Investment Banking & Asset Management                 Finance
# 4                        Insurance Carriers               Insurance
# ...                                     ...                     ...
# 2523           Computer Hardware & Software  Information Technology
# 2524                 Staffing & Outsourcing       Business Services
# 2525                            IT Services  Information Technology
# 2526                                     -1                      -1
# 2527                 Staffing & Outsourcing       Business Services
#
#                          Revenue                       Competitors Easy Apply
# 0       $10 to $25 million (USD)               WCI Consulting, PwC         -1
# 1       $25 to $50 million (USD)                                -1         -1
# 2        $5 to $10 million (USD)                                -1         -1
# 3       Unknown / Non-Applicable                                -1         -1
# 4     $100 to $500 million (USD)  Travelers, Chubb, Crum & Forster       True
# ...                          ...                               ...        ...
# 2523      $1 to $5 million (USD)                                -1         -1
# 2524     $5 to $10 million (USD)                                -1         -1
# 2525  $100 to $500 million (USD)                                -1         -1
# 2526    Unknown / Non-Applicable                                -1         -1
# 2527    $25 to $50 million (USD)                                -1         -1
#
# [2528 rows x 15 columns]

# %%
data_engineer_jobs.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %% [markdown]
# Dataset có 2528 dòng và 15 cột, đúng như miêu tả.

# %% [markdown]
# ### Xử lí missing value

# %% [markdown]
# Xem dữ liệu, có thể thấy tác giả đã đặt các giá trị thiếu thành `-1` và `Unknown / Non-Applicable` thay vì là `null` hay `nan`.
# Đầu tiên chuyển các giá trị đó về thành `nan`.

# %%
data_engineer_jobs['Revenue'].unique()
# Out:
# array(['$10 to $25 million (USD)', '$25 to $50 million (USD)',
#        '$5 to $10 million (USD)', 'Unknown / Non-Applicable',
#        '$100 to $500 million (USD)', '$2 to $5 billion (USD)',
#        '$500 million to $1 billion (USD)', '$50 to $100 million (USD)',
#        '$10+ billion (USD)', '$1 to $2 billion (USD)',
#        '$1 to $5 million (USD)', 'Less than $1 million (USD)',
#        '$5 to $10 billion (USD)', '-1'], dtype=object)

# %%
data_engineer_jobs.replace({-1: np.nan, '-1': np.nan}, inplace=True)

# %%
data_engineer_jobs.isna().sum() / len(data_engineer_jobs) * 100
# Out:
# Job Title             0.000000
# Salary Estimate       0.000000
# Job Description       0.000000
# Rating                9.256329
# Company Name          0.000000
# Location              0.000000
# Headquarters          4.905063
# Size                  4.707278
# Founded              22.587025
# Type of ownership     4.707278
# Industry             14.952532
# Sector               14.833861
# Revenue               4.707278
# Competitors          69.185127
# Easy Apply           94.224684
# dtype: float64

# %% [markdown]
# **Xoá các dòng bị thiếu giá trị quá nhiều**

# %%
data_engineer_jobs[data_engineer_jobs['Revenue'].isna()]
# Out:
#                                        Job Title  \
# 114                                Data Engineer
# 161                                Data Engineer
# 163                                Data Engineer
# 165                                Data Engineer
# 182                                Data Engineer
# ...                                          ...
# 2414             Data Engineer - Big Data-Hadoop
# 2415           Developer, Data Engineer Big Data
# 2419                       Data Network Engineer
# 2427                Data Integration Engineer II
# 2447  Data Engineer/Irving TX/6+ months Contract
#
#                    Salary Estimate  \
# 114    $84K-$113K (Glassdoor est.)
# 161   $105K-$121K (Glassdoor est.)
# 163   $105K-$121K (Glassdoor est.)
# 165   $105K-$121K (Glassdoor est.)
# 182   $105K-$121K (Glassdoor est.)
# ...                            ...
# 2414    $30K-$60K (Glassdoor est.)
# 2415    $30K-$60K (Glassdoor est.)
# 2419    $30K-$60K (Glassdoor est.)
# 2427  $100K-$160K (Glassdoor est.)
# 2447  $100K-$160K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 114   We are looking for a data engineer to manage a...     NaN
# 161   What You'll Do:We are looking for a data engin...     NaN
# 163   Job Details\n\nLevel\n\nExperienced\n\nJob Loc...     NaN
# 165   About UsSimon Data was founded in 2015 by a te...     NaN
# 182   Role Background:\n\nWere looking for agreat Da...     NaN
# ...                                                 ...     ...
# 2414  Analyze and understand data sources & APIs• De...     NaN
# 2415  OTSI is searching for a Developer, Data Engine...     NaN
# 2419  This position will be responsible for the miss...     NaN
# 2427  Job Description\nThe Data Integration Engineer...     NaN
# 2447  Data Platform Engineer\no Apache Pinot and Apa...     NaN
#
#                                            Company Name           Location  \
# 114                              Pierce Technology Corp       New York, NY
# 161                                        Atom Finance       New York, NY
# 163   Greater New York Mutual Insurance Companies (GNY)       New York, NY
# 165                                           Simondata       New York, NY
# 182                           Carter Wellington Limited       New York, NY
# ...                                                 ...                ...
# 2414           Object Technology Solutions, Inc. (OTSI)         Irving, TX
# 2415           Object Technology Solutions, Inc. (OTSI)         Irving, TX
# 2419                      Brightstar Media Organization  Grand Prairie, TX
# 2427                                 Outsourced CIO LLC      Arlington, TX
# 2447                            Suncap Technology, Inc.         Irving, TX
#
#      Headquarters Size  Founded Type of ownership Industry Sector Revenue  \
# 114           NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 161           NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 163           NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 165           NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 182           NaN  NaN      NaN               NaN      NaN    NaN     NaN
# ...           ...  ...      ...               ...      ...    ...     ...
# 2414          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2415          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2419          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2427          NaN  NaN      NaN               NaN      NaN    NaN     NaN
# 2447          NaN  NaN      NaN               NaN      NaN    NaN     NaN
#
#      Competitors Easy Apply
# 114          NaN        NaN
# 161          NaN        NaN
# 163          NaN        NaN
# 165          NaN        NaN
# 182          NaN        NaN
# ...          ...        ...
# 2414         NaN        NaN
# 2415         NaN        NaN
# 2419         NaN        NaN
# 2427         NaN        NaN
# 2447         NaN        NaN
#
# [119 rows x 15 columns]

# %% [markdown]
# Tổng cộng có 119 dòng có giá trị `Revenue` là -1, và có thể thấy các cột còn lại (trừ `Job Title`, `Salary`, `Company Name`, `Location` và `Headquaters`) đểu có giá trị -1, tức là job này và công ty này không có bất cứ thông tin nào có giá trị để đưa vào phân tích. Vì vậy ta sẽ xóa luôn các dòng này.

# %%
data_engineer_jobs.drop(data_engineer_jobs[data_engineer_jobs['Revenue'].isna()].index, axis=0, inplace=True)
data_engineer_jobs.shape
# Out:
# (2409, 15)

# %% [markdown]
# Dữ liệu còn lại 2409 dòng với cột Revenue không có giá trị -1 mà chỉ còn giá trị Unknown / Non-Applicable, ta sẽ xử lý chúng sau.

# %%
data_engineer_jobs.isna().sum() / len(data_engineer_jobs) * 100
# Out:
# Job Title             0.000000
# Salary Estimate       0.000000
# Job Description       0.000000
# Rating                4.773765
# Company Name          0.000000
# Location              0.000000
# Headquarters          0.207555
# Size                  0.000000
# Founded              18.762972
# Type of ownership     0.000000
# Industry             10.751349
# Sector               10.626816
# Revenue               0.000000
# Competitors          67.662931
# Easy Apply           93.939394
# dtype: float64

# %% [markdown]
# Cột Competitors và Easy Apply có rất nhiều missing value, và dữ liệu hai cột này cũng không cần thiết cho câu hỏi, vì vậy sẽ xóa hai cột này để làm sạch dữ liệu.

# %%
data_engineer_jobs = data_engineer_jobs.drop(columns=['Competitors', 'Easy Apply'])

# %% [markdown]
# ### Xử lí các cột numeric

# %%
data_engineer_jobs.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue'],
#       dtype='object')

# %% [markdown]
# Có đầy đủ các cột và nó có tên đúng như mô tả. Tiếp theo ta sẽ xem kiểu dữ liệu của cột.

# %%
data_engineer_jobs.dtypes
# Out:
# Job Title             object
# Salary Estimate       object
# Job Description       object
# Rating               float64
# Company Name          object
# Location              object
# Headquarters          object
# Size                  object
# Founded              float64
# Type of ownership     object
# Industry              object
# Sector                object
# Revenue               object
# dtype: object

# %% [markdown]
# Theo lí thuyết ta sẽ phải có những cột này là kiểu numeric: `Salary Estimate`, `Rating`, `Founded`, `Size`, `Revenue`. Tuy nhiên theo kết quả trên thì các cột `Salary Estimate`, `Size` và `Revenue` chưa có đúng kiểu dữ liệu (object thay vì int hoặc float). Ta tiến hành đổi kiểu dữ liệu lại cho 3 cột này.

# %% [markdown]
# **Đổi kiểu dữ liệu cột `Salary Estimate`**

# %%
data_engineer_jobs["Salary Estimate"].unique()
# Out:
# array(['$80K-$150K (Glassdoor est.)', '$73K-$94K (Glassdoor est.)',
#        '$85K-$154K (Glassdoor est.)', '$84K-$113K (Glassdoor est.)',
#        '$57K-$75K (Glassdoor est.)', '$105K-$121K (Glassdoor est.)',
#        '$92K-$117K (Glassdoor est.)', '$88K-$136K (Glassdoor est.)',
#        '$95K-$167K (Glassdoor est.)', '$79K-$146K (Glassdoor est.)',
#        '$93K-$106K (Glassdoor est.)', '$115K-$201K (Glassdoor est.)',
#        '$94K-$164K (Glassdoor est.)', '$49K-$98K (Glassdoor est.)',
#        '$56K-$108K (Glassdoor est.)', '$85K-$158K (Glassdoor est.)',
#        '$133K-$210K (Glassdoor est.)', '$95K-$99K (Glassdoor est.)',
#        '$67K-$72K (Glassdoor est.)', '$53K-$100K (Glassdoor est.)',
#        '$81K-$100K (Glassdoor est.)', '$94K-$107K (Glassdoor est.)',
#        '$43K-$84K (Glassdoor est.)', '$62K-$92K (Glassdoor est.)',
#        '$55K-$106K (Glassdoor est.)', '$69K-$103K (Glassdoor est.)',
#        '$54K-$113K (Glassdoor est.)', '$74K-$123K (Glassdoor est.)',
#        '$69K-$122K (Glassdoor est.)', '$79K-$104K (Glassdoor est.)',
#        '$81K-$141K (Glassdoor est.)', '$87K-$104K (Glassdoor est.)',
#        '$73K-$126K (Glassdoor est.)', '$58K-$94K (Glassdoor est.)',
#        '$74K-$145K (Glassdoor est.)', '$66K-$122K (Glassdoor est.)',
#        '$118K-$187K (Glassdoor est.)', '$70K-$138K (Glassdoor est.)',
#        '$57K-$92K (Glassdoor est.)', '$57K-$97K (Glassdoor est.)',
#        '$65K-$101K (Glassdoor est.)', '$94K-$166K (Glassdoor est.)',
#        '$57K-$108K (Glassdoor est.)', '$54K-$104K (Glassdoor est.)',
#        '$55K-$105K (Glassdoor est.)', '$71K-$130K(Employer est.)',
#        '$154K-$281K (Glassdoor est.)', '$74K-$93K (Glassdoor est.)',
#        '$75K-$135K (Glassdoor est.)', '$44K-$80K (Glassdoor est.)',
#        '$28K-$53K (Glassdoor est.)', '$67K-$107K (Glassdoor est.)',
#        '$52K-$63K (Glassdoor est.)', '$59K-$135K (Glassdoor est.)',
#        '$77K-$181K (Glassdoor est.)', '$113K-$198K (Glassdoor est.)',
#        '$46K-$92K (Glassdoor est.)', '$79K-$132K (Glassdoor est.)',
#        '$191K-$217K (Glassdoor est.)', '$140K-$151K (Glassdoor est.)',
#        '$106K-$127K (Glassdoor est.)', '$64K-$124K (Glassdoor est.)',
#        '$66K-$113K (Glassdoor est.)', '$105K-$110K (Glassdoor est.)',
#        '$60K-$109K (Glassdoor est.)', '$74K-$134K (Glassdoor est.)',
#        '$110K-$188K (Glassdoor est.)', '$91K-$166K (Glassdoor est.)',
#        '$164K-$192K (Glassdoor est.)', '$108K-$199K (Glassdoor est.)',
#        '$77K-$145K (Glassdoor est.)', '$54K-$103K (Glassdoor est.)',
#        '$108K-$127K (Glassdoor est.)', '$100K-$181K (Glassdoor est.)',
#        '$88K-$163K (Glassdoor est.)', '$79K-$96K (Glassdoor est.)',
#        '$99K-$177K (Glassdoor est.)', '$52K-$85K (Glassdoor est.)',
#        '$67K-$126K (Glassdoor est.)', '$82K-$130K(Employer est.)',
#        '$27K-$50K (Glassdoor est.)', '$44K-$141K (Glassdoor est.)',
#        '$39K-$77K (Glassdoor est.)', '$45K-$76K (Glassdoor est.)',
#        '$37K-$75K (Glassdoor est.)', '$65K-$120K (Glassdoor est.)',
#        '$30K-$60K (Glassdoor est.)', '$100K-$160K (Glassdoor est.)',
#        '$48K-$74K (Glassdoor est.)', '$56K-$89K (Glassdoor est.)',
#        '$76K-$128K (Glassdoor est.)'], dtype=object)

# %% [markdown]
# Tất cả các giá trị đều được biểu diễn trong một khoảng cố định. `Glassdoor est.` là mức lương ước tính trên trang việc làm trực tuyến `Glassdoor`.
# Ta chia giá trị cột này thành 2 cột Upper và Lower, sau đó đổi giá trị của cột từ mức lương min-max thành mức lương trung bình.
# Rất may là cột này không có giá trị thiếu.

# %%
list_upper =[]
list_lower = []
list_avg = []
def split_salary(x):
    S = [int(s) for s in re.findall(r'\d+', x)]
    list_lower.append(S[0])
    list_upper.append(S[1])
    list_avg.append((S[0] + S[1]) / 2)

for x in data_engineer_jobs["Salary Estimate"]:
    split_salary(x)

data_engineer_jobs["Salary Lower"] = list_lower
data_engineer_jobs["Salary Upper"] = list_upper
data_engineer_jobs["Salary Estimate"] = list_avg
data_engineer_jobs = data_engineer_jobs.rename(columns={"Salary Estimate": "Salary est. (thousand USD)"})

# %% [markdown]
# **Đổi kiểu dữ liệu cột `Size`**

# %%
data_engineer_jobs['Size'].unique()
# Out:
# array(['1 to 50 employees', '51 to 200 employees',
#        '501 to 1000 employees', '201 to 500 employees',
#        '1001 to 5000 employees', '10000+ employees',
#        '5001 to 10000 employees', 'Unknown'], dtype=object)

# %% [markdown]
# Ta thấy chỉ có 7 giá trị phân biệt và 1 giá trị missing (unknown).
# Vậy ta quy đổi thành các giá trị từ 1-7 thể hiện cho quy mô tăng dần như sau:
# - Mức độ 1: 1 to 50 employees
# - Mức độ 2: 51 to 200 employees
# - Mức độ 3: 201 to 500 employees
# - Mức độ 4: 501 to 1000 employees
# - Mức độ 5: 1001 to 5000 employees
# - Mức độ 6: 5001 to 10000 employees
# - Mức độ 7: 10000+ employees
# Các giá trị unknown ta sẽ để bằng `nan`.

# %%
def transform_size(x):
    if x == '1 to 50 employees':
        return 1
    elif x == '51 to 200 employees':
        return 2
    elif x == '201 to 500 employees':
        return 2
    elif x == '501 to 1000 employees':
        return 4
    elif x == '1001 to 5000 employees':
        return 5
    elif x == '5001 to 10000 employees':
        return 6
    elif x == '10000+ employees':
        return 7
    else:
        return np.nan

data_engineer_jobs['Size'] = data_engineer_jobs['Size'].apply(transform_size)

# %% [markdown]
# **Đổi kiểu dữ liệu cột `Revenue`**

# %%
data_engineer_jobs['Revenue'].unique()
# Out:
# array(['$10 to $25 million (USD)', '$25 to $50 million (USD)',
#        '$5 to $10 million (USD)', 'Unknown / Non-Applicable',
#        '$100 to $500 million (USD)', '$2 to $5 billion (USD)',
#        '$500 million to $1 billion (USD)', '$50 to $100 million (USD)',
#        '$10+ billion (USD)', '$1 to $2 billion (USD)',
#        '$1 to $5 million (USD)', 'Less than $1 million (USD)',
#        '$5 to $10 billion (USD)'], dtype=object)

# %% [markdown]
# Ta thấy có rất nhiều cách biểu diễn khác nhau cho cột này (có khoảng from..to, có con số X+, có less than).
# Do số tiền chỉ có đơn vị là triệu (million) và tỷ (billion) nên ta sẽ đổi hết giá trị về thành đơn vị tỉ đô
# Đổi giá trị cột `Revenue` từ các khoảng doanh thu bằng `giá trị cao nhất (max)` trong khoảng:
# - Các dòng có giá trị X+ sẽ được quy ước là X+1
# - Các dòng có giá trị Less than X quy ước là X
# - Các dòng Unknown sẽ được quy ước là nan

# %%
def find_max_revenue(x):
    if x == 'Unknown / Non-Applicable':
        return np.nan
    else:
        S = [int(s) for s in re.findall(r'\d+', x)]
        if 'billion' in x and 'million' not in x:
            S = [s*1000 for s in S]
        if '+' in x:
            S.append(S[0] + 1)
        if 'Less than' in x:
            S.append(S[0])
            S[0] = 0
        return S[1]
data_engineer_jobs['Revenue'] = data_engineer_jobs['Revenue'].apply(find_max_revenue)
data_engineer_jobs = data_engineer_jobs.rename(columns={'Revenue': 'Revenue (million USD)'})

# %% [markdown]
# ### Xử lí các cột category

# %% [markdown]
# Ở cột `Company Name`, ta thấy có phần "\n rating" phía sau tên công ty là dư thừa (vì đã có cột `rating` riêng), vì vậy ta xoá nó đi.

# %%
data_engineer_jobs['Company Name'] = data_engineer_jobs['Company Name'].str.partition("\n")

# %% [markdown]
# Ta xem xét một vài thống kê trong các cột category:

# %%
data_engineer_jobs.describe(include=[object])
# Out:
#             Job Title                                    Job Description  \
# count            2409                                               2409
# unique           1221                                               2190
# top     Data Engineer  Organization: Accenture Federal Services\n\nLo...
# freq              438                                                  7
#
#        Company Name    Location  Headquarters  Type of ownership     Industry  \
# count          2409        2409          2404               2409         2150
# unique         1365         111           435                 13           83
# top          Amazon  Austin, TX  New York, NY  Company - Private  IT Services
# freq             28         195           178               1392          355
#
#                         Sector
# count                     2153
# unique                      24
# top     Information Technology
# freq                       890

# %% [markdown]
# ### Xử lí cột `Job Title`
#
# Ở đây ta quan tâm đến 2 job là Data Engineer và Senior Data Engineer, và có rất nhiều job thuộc 2 loại này nhưng có title khác nhau, ví dụ: Big Data Engineer, Data Engineer II,... Vì vậy cần đồng bộ các title này trở về 2 loại chính. Đầu tiên là sửa lại title chứa Sr. thành Senior để dễ xử lý.

# %%
data_engineer_jobs['Job Title'] = data_engineer_jobs['Job Title'].str.replace('Sr.','Senior', regex=True)

# %% [markdown]
# Tiếp theo ta thay đổi tất cả title chứa cụm 'Data Engineer' -> Data Engineer và tương tự với Senior Data Engineer và lưu lại vào cột Job Title.

# %%
title = []
job_title = data_engineer_jobs['Job Title'].values
for each in job_title:
    if 'Senior Data Engineer' not in each:
        #lệnh re replace các title Data Engineer
        each = re.sub("[\w\s\S]*Data[\w\s\S]*Engineer[\w\s\S]*",'Data Engineer',each,flags=re.IGNORECASE) 
    else:
        #lệnh re thay đổi các title Senior Data Engineer
        each = re.sub("[\w\s\S]*Senior[\w\s\S]*Data[\w\s\S]*Engineer[\w\s\S]*",'Senior Data Engineer', each,flags=re.IGNORECASE)
    title.append(each)

# %%
data_engineer_jobs['Job Title']= title
data_engineer_jobs['Job Title'].value_counts()
# Out:
# Data Engineer                                                         1191
# Senior Data Engineer                                                   146
# Software Engineer                                                       90
# Machine Learning Engineer                                               17
# Systems Engineer                                                        13
#                                                                       ...
# Cyber Defense Infrastructure Engineer Managed Detection & Response       1
# Senior Software Engineer (Java/Spring)                                   1
# Network VoIP Engineer - Cisco                                            1
# Electrical Engineer/Battery Specialist                                   1
# Product Operations Engineer                                              1
# Name: Job Title, Length: 745, dtype: int64

# %%
title = []
job_title = data_engineer_jobs['Job Title'].values
for each in job_title:
    if 'Software Engineer' in each:
        split_string = each.split("Engineer", 1)
        each = split_string[0] + ' Engineer'
    title.append(each)

# %%
data_engineer_jobs['Job Title']= title
data_engineer_jobs['Job Title'].value_counts()
# Out:
# Data Engineer                   1191
# Software  Engineer               172
# Senior Data Engineer             146
# Senior Software  Engineer         39
# Machine Learning Engineer         17
#                                 ...
# Tier II TAC Engineer               1
# Data Steward                       1
# Full Stack Engineer (PHP)          1
# Wiring Installation Engineer       1
# Product Operations Engineer        1
# Name: Job Title, Length: 639, dtype: int64

# %% [markdown]
# **Xử lí cột `Location`**
#
# Cột `Location` có hai giá trị là tên thành phố và tên bang, vậy nên ta tiến hành tách cột `Location` ban đầu thành hai cột `Location State` và `Location City` để dễ dàng trả lời câu hỏi

# %%
data_engineer_jobs['Location State'] = data_engineer_jobs['Location'].str.partition(", ")[2] #lấy từ sau dấu phẩy
data_engineer_jobs['Location City'] = data_engineer_jobs['Location'].str.partition(",")[0] #lấy từ đầu tiên
data_engineer_jobs = data_engineer_jobs.drop(columns=['Location'])

# %% [markdown]
# ## Các câu hỏi cần trả lời

# %% [markdown]
# ### 1- Mức lương trung bình của từng job là bao nhiêu? Mức lương cho Senior data là bao nhiêu?

# %%
AVG_salary_by_job = data_engineer_jobs[["Job Title","Salary est. (thousand USD)"]].groupby(["Job Title"]).mean().sort_values(by=['Salary est. (thousand USD)'], ascending=False)
AVG_salary_by_job
# Out:
#                                                     Salary est. (thousand USD)
# Job Title
# machine learning Engineer with AWS                                       217.5
# Python Software  Engineer                                                217.5
# Validations Manager / Engineer                                           204.0
# Data Analyst - EDSS                                                      204.0
# Software Architect (Distinguished Software  Eng...                       204.0
# ...                                                                        ...
# Process Optimization Engineer Assistant Vice Pr...                        38.5
# Process Optimization Engineer - Assistant Vice ...                        38.5
# Engineer Quality Control Inspector with Securit...                        38.5
# Principal Systems Engineer                                                38.5
# Software Support Engineer - C#                                            38.5
#
# [639 rows x 1 columns]

# %%
AVG_salary_by_job[AVG_salary_by_job.index == 'Senior Data Engineer'].values
# Out:
# array([[108.00684932]])

# %% [markdown]
# Như vậy, Senior Data Engineer có mức lương trung bình là 108 ngàn USD/năm

# %% [markdown]
# ### 2 - Top 5 lĩnh vực tuyển dụng data engineer (tất cả các vị trí) nhiều nhất?

# %%
sector = data_engineer_jobs[data_engineer_jobs['Job Title'] == "Data Engineer"]['Sector'].value_counts()
sector.head(5)
# Out:
# Information Technology    468
# Business Services         223
# Finance                    99
# Insurance                  39
# Health Care                33
# Name: Sector, dtype: int64

# %%
fig = px.pie(sector, names=sector[sector>10].index, values=sector[sector>10].values, title='Sector needs data jobs most',\
            width= 800, height=600, color_discrete_sequence= px.colors.qualitative.Plotly)
fig.show()
# Out:
# <div>                            <div id="518a1b1e-0f80-494a-a32c-a02016308e0f" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("518a1b1e-0f80-494a-a32c-a02016308e0f")) {                    Plotly.newPlot(                        "518a1b1e-0f80-494a-a32c-a02016308e0f",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "label=%{label}<br>value=%{value}<extra></extra>", "labels": ["Information Technology", "Business Services", "Finance", "Insurance", "Health Care", "Media", "Accounting & Legal", "Education", "Retail", "Manufacturing", "Telecommunications", "Biotech & Pharmaceuticals"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [468, 223, 99, 39, 33, 32, 18, 17, 16, 14, 14, 11]}],                        {"height": 600, "legend": {"tracegroupgap": 0}, "piecolorway": ["#636EFA", "#EF553B", "#00CC96", "#AB63FA", "#FFA15A", "#19D3F3", "#FF6692", "#B6E880", "#FF97FF", "#FECB52"], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"] ...

# %% [markdown]
# **Vậy trong mỗi lĩnh vực, số lượng tuyển dụng data engineer của các ngành nghề như thế nào?**

# %%
industry = data_engineer_jobs[data_engineer_jobs['Job Title'] == "Data Engineer"]
industry = industry.groupby(['Sector', 'Industry']).size().sort_values(ascending=False)
industry = industry.sort_index()
industry = industry.reset_index()
industry = industry.rename(columns={0: "Recruitment Number"})
industry
# Out:
#                               Sector                     Industry  \
# 0                 Accounting & Legal                   Accounting
# 1                Aerospace & Defense          Aerospace & Defense
# 2   Arts, Entertainment & Recreation                  Photography
# 3   Arts, Entertainment & Recreation          Sports & Recreation
# 4          Biotech & Pharmaceuticals    Biotech & Pharmaceuticals
# ..                               ...                          ...
# 61                Telecommunications  Telecommunications Services
# 62        Transportation & Logistics    Express Delivery Services
# 63        Transportation & Logistics     Logistics & Supply Chain
# 64        Transportation & Logistics    Transportation Management
# 65        Transportation & Logistics                     Trucking
#
#     Recruitment Number
# 0                   18
# 1                    9
# 2                    1
# 3                    2
# 4                   11
# ..                 ...
# 61                   9
# 62                   1
# 63                   5
# 64                   1
# 65                   1
#
# [66 rows x 3 columns]

# %%
fig = px.treemap(industry, path=['Sector', 'Industry'], values='Recruitment Number', title='Recruitment needs for each sector',
                  color='Recruitment Number', color_continuous_scale='RdBu')
                  #color_continuous_midpoint=np.average(industry['Size']))
fig.update_layout(margin = dict(t=35, l=25, r=25, b=25))
fig.show()
# Out:
# <div>                            <div id="5daa44ff-42ce-43e4-9cb1-b9d24cd5fca6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5daa44ff-42ce-43e4-9cb1-b9d24cd5fca6")) {                    Plotly.newPlot(                        "5daa44ff-42ce-43e4-9cb1-b9d24cd5fca6",                        [{"branchvalues": "total", "customdata": [[18.0], [38.0], [9.0], [2.0], [2.0], [29.0], [2.0], [11.0], [3.0], [5.0], [1.0], [1.0], [10.0], [91.0], [1.0], [62.0], [4.0], [4.0], [1.0], [3.0], [2.0], [68.0], [1.0], [4.0], [6.0], [3.0], [4.0], [2.0], [1.0], [2.0], [3.0], [33.0], [9.0], [236.0], [13.0], [26.0], [73.0], [48.0], [6.0], [7.0], [5.0], [1.0], [4.0], [2.0], [1.0], [3.0], [1.0], [4.0], [1.0], [1.0], [1.0], [5.0], [2.0], [6.0], [5.0], [2.0], [110.0], [1.0], [3.0], [8.0], [9.0], [2.0], [1.0], [1.0], [9.0], [5.0], [18.0], [9.0], [1.6666666666666667], [11.0], [78.21973094170404], [1.0], [9.0], [8.058823529411764], [32.898989898989896], [3.0], [33.0], [157.97008547008548], [21.666666666666668], [3.2857142857142856], [6.25], [2.0], [3.0], [6.0], [1.0], [2.5], [7.571428571428571], [3.5]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Recruitment Number_sum=%{value}<br>parent=%{parent}<br>id=%{id}<br>Recruitment Number=%{color}<extra></extra>", "ids": ["Accounting & Legal/Accounting", "Business Services/Advertising & Marketing", "Aerospace & Defense/Aerospace & Defense", "Business Services/Architectural & Engineering Services", "Retail/Automotive Parts & Accessories Stores", "Finance/Banks & Credit Unions", "Retail/Beauty & Personal Accessories Stores", "Biotech & Pharmaceuticals/Biotech & Pharmaceuticals", "Finance/Brokerage Services", "Telecommunications/Cable, Internet & Telephone Providers", "Restaurants, Bars & Food Services/Casual Restaurants", "Manufacturing/Chemical Manufacturing", "Education/Colleges & Universities", "Information Technology/Computer Hardware & Software", "Construction, Repair & Maintenance/Construction", "Business Services/Consulting", "Manufacturing/Consumer Products Manufacturing", "Retail/Department, Clothing, & Shoe Stores", "Education/Education Training Services", "Manufacturing/Electrical & Electronic Manufacturing", "Oil, Gas, Energy & Utilities/Energy", "Information Technology/Enterprise Software & Network Solutions", "Transportation & Logistics/Express Delivery Services", "Government/Federal Agencies", "Finance/Financial Analytics & Research", "Finance/Financial Transaction Processing", "Manufacturing/Food & Beverage Manufacturing", "Retail/Food & Beverage Stores", "Retail/Gas Stations", "Non-Profit/Grantmaking Foundations", "Retail/Grocery Stores & Supermarkets", "Health Care/Health Care Services & Hospitals", "Consumer Services/Health, Beauty, & Fitness", "Information Technology/IT Services", "Insurance/Insurance Agencies & Brokerages", "Insurance/Insurance Carriers", "Information Technology/Internet", "Finance/Investment Banking & Asset Management", "Education/K-12 Education", "Finance/Lending", "Transportation & Logistics/Logistics & Supply Chain", "Business Services/Membership Organizations", "Media/Motion Picture Production & Distribution", "Government/Municipal Governments", "Media/Music Production & Distribution", "Media/News Outlet", "Oil, Gas, Energy & Utilities/Oil & Gas Exploration & Production", "Oil, Gas, Energy & Utilities/Oil & Gas Services", "Retail/Other Retail Stores", "Retail/Pet & Pet Supplies Stores", "Arts, Entertainment & Recreation/Photography", "Media/Publishing", "Media/Radio", "Real Estate/Real Estate", "Business Services/Research & Development", "Arts, Entertainment & Recreation/Sports & Recreation", "Business Services/Staffing & Outsourcing", "Government/State & Regional Agencies", "Finance/Stock Exchanges", "M ...

# %% [markdown]
# ### 3 - Top 10 location tuyển dụng nhiều vị trí nhất?

# %% [markdown]
# Ta tách cột `location` ra thành hai cột nhỏ là `State` và `City` với State là 2 kí tự cuối của `Location`. Sau đó thực hiện đếm giá trị của từng State

# %% [markdown]
# Do chỉ có 9 kí hiệu nên ta tiến hành đổi tên cho dễ đọc.

# %%
jobs_by_location = data_engineer_jobs['Location State'].value_counts()
jobs_by_location = jobs_by_location.reset_index()
jobs_by_location.rename(columns={'Location State': 'Jobs Count', 'index': 'State'}, inplace=True)
jobs_by_location['Name State'] = jobs_by_location['State'].replace({'PA': 'Pennsylvania', 'AZ': 'Arizona', 'TX': 'Texas', 'IL': 'Illinois', 'FL': 'Florida', 
                           'NY': 'New York', 'DE': 'Delaware', 'CA': 'California', 'NJ': 'New Jersey'})
jobs_by_location
# Out:
#   State  Jobs Count    Name State
# 0    TX         962         Texas
# 1    CA         566    California
# 2    AZ         190       Arizona
# 3    IL         188      Illinois
# 4    NY         181      New York
# 5    PA         166  Pennsylvania
# 6    FL         118       Florida
# 7    NJ          22    New Jersey
# 8    DE          16      Delaware

# %% [markdown]
# Ta thấy tất cả nơi làm việc đều là ở Mĩ, chứng tỏ rằng dữ liệu này được lấy từ các công ty tại Mĩ hoặc có chi nhánh ở Mĩ. Bang Texas chiếm số lượng áp đảo về nhu cầu tuyển dụng trong ngành này.

# %%
fig = px.choropleth(data_frame=jobs_by_location ,locations=jobs_by_location['State'], locationmode="USA-states", color=jobs_by_location['Jobs Count'], 
                    scope="usa", title="States need many jobs", hover_data=['Name State', 'Jobs Count'])
fig.show()
# Out:
# <div>                            <div id="84a104c5-4908-456f-888b-86e0dd064e59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84a104c5-4908-456f-888b-86e0dd064e59")) {                    Plotly.newPlot(                        "84a104c5-4908-456f-888b-86e0dd064e59",                        [{"coloraxis": "coloraxis", "customdata": [["Texas", 962], ["California", 566], ["Arizona", 190], ["Illinois", 188], ["New York", 181], ["Pennsylvania", 166], ["Florida", 118], ["New Jersey", 22], ["Delaware", 16]], "geo": "geo", "hovertemplate": "State=%{location}<br>Name State=%{customdata[0]}<br>Jobs Count=%{z}<extra></extra>", "locationmode": "USA-states", "locations": ["TX", "CA", "AZ", "IL", "NY", "PA", "FL", "NJ", "DE"], "name": "", "type": "choropleth", "z": [962, 566, 190, 188, 181, 166, 118, 22, 16]}],                        {"coloraxis": {"colorbar": {"title": {"text": "Jobs Count"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "scope": "usa"}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram ...

# %% [markdown]
# ### 4 - Ngành nào có mức lương trung bình (trên tất cả job) cao nhất và thấp nhất?

# %%
#Code
salary_by_sector = data_engineer_jobs[['Sector', 'Industry', 'Salary est. (thousand USD)']]
salary_by_sector = salary_by_sector.groupby(['Sector', 'Industry']).mean()
salary_by_sector = salary_by_sector.sort_index()
salary_by_sector = salary_by_sector.reset_index()
salary_by_sector
# Out:
#                               Sector                   Industry  \
# 0                 Accounting & Legal                 Accounting
# 1                 Accounting & Legal                      Legal
# 2                Aerospace & Defense        Aerospace & Defense
# 3             Agriculture & Forestry            Food Production
# 4   Arts, Entertainment & Recreation                   Gambling
# ..                               ...                        ...
# 78        Transportation & Logistics  Transportation Management
# 79        Transportation & Logistics     Truck Rental & Leasing
# 80        Transportation & Logistics                   Trucking
# 81                  Travel & Tourism                   Airlines
# 82                  Travel & Tourism  Hotels, Motels, & Resorts
#
#     Salary est. (thousand USD)
# 0                   107.153846
# 1                    83.000000
# 2                    90.867021
# 3                    66.000000
# 4                    91.500000
# ..                         ...
# 78                   79.055556
# 79                   95.500000
# 80                   91.500000
# 81                   97.750000
# 82                   82.500000
#
# [83 rows x 3 columns]

# %%
fig = px.treemap(salary_by_sector, path=['Sector', 'Industry'], values='Salary est. (thousand USD)', title='Means salary for each sector',
                  color='Salary est. (thousand USD)', color_continuous_scale='RdBu')
fig.update_layout(margin = dict(t=35, l=25, r=25, b=25))
fig.show()
# Out:
# <div>                            <div id="f777338a-d140-48af-8623-bf5e2cfd83f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f777338a-d140-48af-8623-bf5e2cfd83f8")) {                    Plotly.newPlot(                        "f777338a-d140-48af-8623-bf5e2cfd83f8",                        [{"branchvalues": "total", "customdata": [[107.15384615384617], [113.34745762711864], [90.86702127659575], [97.75], [84.16666666666667], [97.0], [102.07142857142857], [98.0], [112.31428571428572], [96.4], [91.5], [87.33333333333333], [100.6], [90.25], [93.89285714285714], [109.69057377049181], [85.64285714285714], [96.23232323232324], [95.41666666666667], [96.5], [105.6875], [105.0], [118.94444444444444], [89.53333333333333], [105.51398601398601], [150.25], [104.5], [79.775], [106.91666666666666], [101.29166666666666], [92.11111111111111], [113.25], [66.0], [91.5], [111.0], [105.75], [94.94444444444444], [136.16666666666666], [106.23529411764706], [99.26923076923077], [38.5], [82.5], [99.16338028169014], [85.05], [98.57142857142857], [93.12295081967214], [109.14137931034483], [94.07894736842105], [113.19999999999999], [83.0], [85.86363636363636], [112.65], [116.5], [73.5], [114.41666666666666], [98.0], [113.0], [88.5], [116.75], [73.81818181818181], [96.83333333333333], [83.5], [98.5], [104.14285714285714], [85.28571428571429], [92.5], [85.78125], [78.1], [109.0], [96.12376237623762], [98.25], [105.0], [115.38461538461539], [109.16666666666666], [101.58695652173911], [94.72727272727272], [79.05555555555556], [95.5], [91.5], [118.71428571428571], [60.5], [125.66666666666667], [111.375], [96.6109658949465], [90.86702127659575], [66.0], [100.18561872909699], [112.31428571428572], [100.18554922198163], [85.64285714285714], [99.26923076923077], [104.63266901203527], [99.26099799762841], [92.8217122543248], [106.23529411764706], [106.04356936331838], [95.92462000390285], [101.8003752247885], [108.41091800494394], [105.75], [103.27821963912817], [85.78125], [100.63945623342174], [95.45578712105807], [100.18681228473667], [108.71833916393015], [90.77011095700416]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Salary est. (thousand USD)_sum=%{value}<br>parent=%{parent}<br>id=%{id}<br>Salary est. (thousand USD)=%{color}<extra></extra>", "ids": ["Accounting & Legal/Accounting", "Business Services/Advertising & Marketing", "Aerospace & Defense/Aerospace & Defense", "Travel & Tourism/Airlines", "Business Services/Architectural & Engineering Services", "Retail/Automotive Parts & Accessories Stores", "Finance/Banks & Credit Unions", "Retail/Beauty & Personal Accessories Stores", "Biotech & Pharmaceuticals/Biotech & Pharmaceuticals", "Finance/Brokerage Services", "Business Services/Building & Personnel Services", "Telecommunications/Cable, Internet & Telephone Providers", "Restaurants, Bars & Food Services/Casual Restaurants", "Manufacturing/Chemical Manufacturing", "Education/Colleges & Universities", "Information Technology/Computer Hardware & Software", "Construction, Repair & Maintenance/Construction", "Business Services/Consulting", "Manufacturing/Consumer Products Manufacturing", "Restaurants, Bars & Food Services/Convenience Stores & Truck Stops", "Retail/Department, Clothing, & Shoe Stores", "Education/Education Training Services", "Manufacturing/Electrical & Electronic Manufacturing", "Oil, Gas, Energy & Utilities/Energy", "Information Technology/Enterprise Software & Network Solutions", "Transportation & Logistics/Express Delivery Services", "Restaurants, Bars & Food Services/Fast-Food & Quick-Service Restaurants", "Government/Federal Agencies", "Finance/Financial Analytics & Research", "Finance/Financial Transaction Processing", "Manufacturing/Food & Beverage Manufacturing", ...

# %% [markdown]
# ### 5 - Các skill cần thiết cho các job là gì?

# %%
pg_req = ["python", "c++", "java", "matlab", ".net", "c#", "javascript", "html", "bash"]
pg_lan = np.zeros(len(pg_req))

# %%
def count_pg_lan(language):
    if language == 'c++':
        language = 'c\+\+'
    elif language == '.net':
        language = '\.net'
    elif language == 'c#':
        language = 'c\#'
    tmp = data_engineer_jobs['Job Description'].str.lower()
    return tmp.str.count(language, flags=re.IGNORECASE).sum()

for req in pg_req:
    pg_lan[pg_req.index(req)] = count_pg_lan(req)

pg_lan_df = pd.DataFrame([pg_req, pg_lan]).T
pg_lan_df = pg_lan_df.rename(columns={0: 'Programming Language', 1: 'Count'})
pg_lan_df.sort_values(['Count'], axis=0, ascending=False, inplace=True)
pg_lan_df.set_index('Programming Language', inplace=True)
pg_lan_df
# Out:
#                        Count
# Programming Language
# python                1940.0
# java                  1457.0
# c++                    302.0
# javascript             300.0
# .net                   190.0
# c#                     171.0
# html                   149.0
# bash                   127.0
# matlab                  55.0

# %%
pg_lan_df.plot.bar(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Programming Language'>

# %%
ds_ml_req = ["machine learning","regression","stat","numpy","pandas","data visualization","data analysis"," ai ","nlp","deep learning"]
ds_ml_count = np.zeros(len(ds_ml_req))
def count_skills_ds_ml(skill):
    tmp = data_engineer_jobs['Job Description'].str.lower()
    if skill == 'machine learning':
        return tmp.str.count(skill, flags=re.IGNORECASE).sum() + tmp.str.count(' ml ', flags=re.IGNORECASE).sum()
    elif skill == 'deep learning':
        return tmp.str.count(skill, flags=re.IGNORECASE).sum() + tmp.str.count(' dl ', flags=re.IGNORECASE).sum()
    return tmp.str.count(skill, flags=re.IGNORECASE).sum()

for req in ds_ml_req:
    ds_ml_count[ds_ml_req.index(req)] = count_skills_ds_ml(req)

ds_ml_df = pd.DataFrame([ds_ml_req, ds_ml_count]).T
ds_ml_df = ds_ml_df.rename(columns={0: 'DS/ML skill', 1: 'Count'})
ds_ml_df.sort_values(['Count'], axis=0, ascending=False, inplace=True)
ds_ml_df.set_index('DS/ML skill', inplace=True)
ds_ml_df
# Out:
#                      Count
# DS/ML skill
# stat                3465.0
# machine learning     997.0
# data analysis        298.0
# data visualization   191.0
#  ai                  145.0
# deep learning        112.0
# regression            84.0
# nlp                   60.0
# pandas                55.0
# numpy                 38.0

# %%
ds_ml_df.plot.bar(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='DS/ML skill'>

# %%
edu_req = ["master","doctorate","bachelor"]
edu_count = np.zeros(len(edu_req))
def count_edu(degree):
    tmp = data_engineer_jobs['Job Description'].str.lower()
    if degree == 'master':
        return tmp.str.count(degree, flags=re.IGNORECASE).sum() + tmp.str.count(' ms ', flags=re.IGNORECASE).sum() \
                + tmp.str.count('m.s', flags=re.IGNORECASE).sum()
    elif degree == 'bachelor':
        return tmp.str.count(degree, flags=re.IGNORECASE).sum() + tmp.str.count(' bs ', flags=re.IGNORECASE).sum() \
                + tmp.str.count('b.s', flags=re.IGNORECASE).sum()
    else:
        return tmp.str.count(degree, flags=re.IGNORECASE).sum() + tmp.str.count('phd', flags=re.IGNORECASE).sum() \
                + tmp.str.count('ph.d', flags=re.IGNORECASE).sum()


for req in edu_req:
    edu_count[edu_req.index(req)] = count_edu(req)

edu_df = pd.DataFrame([edu_req, edu_count]).T
edu_df = edu_df.rename(columns={0: 'Education', 1: 'Count'})
edu_df.sort_values(['Count'], axis=0, ascending=False, inplace=True)
edu_df.set_index('Education', inplace=True)
edu_df
# Out:
#              Count
# Education
# bachelor   14144.0
# master      8496.0
# doctorate    180.0

# %%
edu_df.plot.bar(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Education'>

# %%
other_skills_req = [" sql ", "nosql", "algorithm", "excel", "sas", "tableau", "power bi", "communication"]
other_skills_count = np.zeros(len(other_skills_req))
def count_other_skills(skill):
    tmp = data_engineer_jobs['Job Description'].str.lower()
    if skill == 'power bi':
        return tmp.str.count(skill, flags=re.IGNORECASE).sum() + tmp.str.count('powerbi', flags=re.IGNORECASE).sum()
    else:
        return tmp.str.count(skill, flags=re.IGNORECASE).sum()

for req in other_skills_req:
    other_skills_count[other_skills_req.index(req)] = count_other_skills(req)

other_skills_df = pd.DataFrame([other_skills_req, other_skills_count]).T
other_skills_df = other_skills_df.rename(columns={0: 'Other skills', 1: 'Count'})
other_skills_df.sort_values(['Count'], axis=0, ascending=False, inplace=True)
other_skills_df.set_index('Other skills', inplace=True)
other_skills_df
# Out:
#                 Count
# Other skills
# communication  1397.0
#  sql           1258.0
# excel          1179.0
# algorithm       512.0
# nosql           455.0
# tableau         354.0
# sas             271.0
# power bi        144.0

# %%
other_skills_df.plot.bar(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Other skills'>

# %% [markdown]
# ### 6 - Mối quan hệ giữa rating và mức lương trung bình?

# %%
fig = px.scatter(data_engineer_jobs, x='Rating', y='Salary Upper',color="Rating",\
                hover_data=['Job Title', 'Location City', 'Sector','Company Name'], \
                title = "Data Engineer jobs",\
                width=800, height=500)
fig.show()
# Out:
# <div>                            <div id="e75244b0-16b4-46f9-9271-825b6c9e0b96" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e75244b0-16b4-46f9-9271-825b6c9e0b96")) {                    Plotly.newPlot(                        "e75244b0-16b4-46f9-9271-825b6c9e0b96",                        [{"customdata": [["Data Engineer", "New York", "Business Services", "Sagence"], ["Senior Data Engineer", "New York", "Information Technology", "Enterprise Integration"], ["Data Engineer", "New York", "Information Technology", "Maestro Technologies"], ["Client Trade Support Engineer", "New York", "Finance", "Jane Street"], ["Data Engineer", "New York", "Insurance", "GNY Insurance Companies"], ["Operations Engineer", "New York", "Insurance", "Oscar Health"], ["Senior Data Engineer", "New York", "Business Services", "Affinity Solutions"], ["Data Engineer", "New York", "Business Services", "NJF Global Holdings"], ["Data Research Developer", "New York", "Finance", "Teza Technologies"], ["Data Engineer", "New York", "Information Technology", "Conductor"], ["Data Engineer", "New York", "Finance", "Jane Street"], ["Data Engineer", "New York", "Information Technology", "Twitter"], ["Software  Engineer", "Jersey City", "Transportation & Logistics", "Verra Mobility"], ["Senior BI Engineer", "New York", "Business Services", "7Park Data"], ["Principal Software  Engineer", "New York", "Information Technology", "Veeva Systems"], ["Data Engineer", "New York", null, "Citadel"], ["Data Engineer", "New York", "Information Technology", "PulsePoint"], ["Service Engineer / Appliance Tech (Bi-lingual English/Korean Preferred)", "Hackensack", null, "CEF Solutions Inc."], ["Software  Engineer", "New York", "Media", "OpenSlate"], ["Data Engineer", "New York", "Business Services", "PA Consulting"], ["Senior Data Engineer", "New York", "Insurance", "Aetna"], ["Data Engineer", "New York", "Manufacturing", "Colgate-Palmolive"], ["Data Engineer", "New York", "Manufacturing", "PepsiCo"], ["Data Engineer", "New York", "Information Technology", "Spotify"], ["Data Engineer", "New York", "Business Services", "Freestar"], ["Data Engineer", "New York", "Information Technology", "Medidata Solutions"], ["Data Engineer", "New York", "Information Technology", "Cockroach Labs"], ["Software  Engineer", "New York", "Finance", "T. Rowe Price"], ["Data Engineer", "New York", "Information Technology", "DoubleVerify"], ["Data Engineer", "New York", "Information Technology", "FourSquare"], ["Data Engineer", "New York", "Information Technology", "Maestro Technologies"], ["Data Engineer", "New York", "Insurance", "GNY Insurance Companies"], ["Data Engineer", "New York", "Manufacturing", "Daily Harvest"], ["Data Engineer", "New York", "Insurance", "Healthfirst"], ["Data Engineer", "New York", "Finance", "Point72"], ["Site Reliability Engineer", "New York", "Finance", "MayStreet"], ["Quality Engineer", "Saddle Brook", "Manufacturing", "Arrow Fastener"], ["Data Engineer", "New York", "Media", "New York Times"], ["Data Engineer", "New York", "Information Technology", "SADA"], ["Data Engineer", "New York", "Information Technology", "Larsen & Toubro Infotech Limited"], ["Data Engineer", "New York", "Consumer Services", "Peloton Interactive, Inc."], ["Data Engineer", "New York", null, "Aptino"], ["Data Engineer", "New York", "Education", "Columbia University"], ["Data Engineer", "New York", "Retail", "Bark & Co"], ["Data Engineer", "New York", "Information Technology", "AVANADE"], ["Data Engineer", "New York", "Media", "New York Times"], ["Data Engineer", "New York", "Information Technology", "Apple"], ["Data Engineer", "New York", "Retail", "Glossier"], ["Data Engineer", "New York", "Finance", "Point72"], ["Data Engineer", "New York", "Finance", "CommonBond"], [" ...

# %% [markdown]
# ### 7 - Tìm job theo các tiêu chí cụ thể (title, salary, location, skills, education,...)
#
# Đầu tiên là tạo một bảng mới để tìm job, bảng này chỉ chứa một số cột cần thiết từ data ban đầu, và thêm các cột skills và education được tách ra từ cột Job Description

# %%
find_jobs = data_engineer_jobs[['Job Title', 'Salary Lower', 'Salary Upper', 'Rating', 'Company Name', 'Location State', 'Location City', 'Size', 'Sector']] 

#filter

# %% [markdown]
# Replace một số từ trong Job Description để thuận tiện trong việc tách cột

# %%
description = data_engineer_jobs["Job Description"].replace({'ms': 'master', 'm.s': 'master', 'bs': 'bachelor', 'b.s': 'bachelor', 'phd': 'doctorate','ph.d': 'doctorate','dl': 'deep learning', 'ml': 'machine learning','powerbi': 'power bi'},regex=True)

# %% [markdown]
# **Thêm các cột skill và education**

# %%
pg_req = ["python", "c++", "java", "matlab", ".net", "c#", "javascript", "html", "bash"]
ds_ml_req = ["machine learning","regression","stat","numpy","pandas","data visualization","data analysis"," ai ","nlp","deep learning"]
edu_req = ["master","bachelor","doctorate"]
other_skills_req = [" sql ", "nosql", "algorithm", "excel", "sas", "tableau", "power bi", "communication"]

# %%
def split_des(row,req):
    temp = []
    for i in req:
        if i in row.lower():
            temp.append(i)
    return ", ".join(map(str,temp))

# %%
list_language = []
list_ds_ml = []
list_edu = []
list_other = []
for row in description:
    list_language.append(split_des(row,pg_req))
    list_ds_ml.append(split_des(row,ds_ml_req))
    list_edu.append(split_des(row,edu_req))
    list_other.append(split_des(row,other_skills_req))

# %%
find_jobs["Language"] = list_language
find_jobs["DS_ML"] = list_ds_ml
find_jobs['Education'] = list_edu
find_jobs['Other skills'] = list_other
# Out:
# <ipython-input-131-d76dd62eb820>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-131-d76dd62eb820>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-131-d76dd62eb820>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-131-d76dd62eb820>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
find_jobs
# Out:
#                           Job Title  Salary Lower  Salary Upper  Rating  \
# 0                     Data Engineer            80           150     4.5
# 1              Senior Data Engineer            80           150     3.4
# 2                     Data Engineer            80           150     5.0
# 3     Client Trade Support Engineer            80           150     4.8
# 4                     Data Engineer            80           150     3.7
# ...                             ...           ...           ...     ...
# 2523                 Cloud Engineer            76           128     4.5
# 2524            Electrical Engineer            76           128     2.9
# 2525                  Data Engineer            76           128     3.7
# 2526                  Data Engineer            76           128     3.5
# 2527                 Cloud Engineer            76           128     3.6
#
#                               Company Name Location State Location City  Size  \
# 0                                  Sagence             NY      New York   1.0
# 1                   Enterprise Integration             NY      New York   2.0
# 2                     Maestro Technologies             NY      New York   2.0
# 3                              Jane Street             NY      New York   4.0
# 4                  GNY Insurance Companies             NY      New York   2.0
# ...                                    ...            ...           ...   ...
# 2523                            PMG Global             TX      Westlake   1.0
# 2524            Albin Engineering Services             TX    Fort Worth   2.0
# 2525  Cincinnati Bell Technology Solutions             TX        Irving   4.0
# 2526                                Schwab             TX      Westlake   NaN
# 2527        SPECTRAFORCE TECHNOLOGIES Inc.             TX      Westlake   4.0
#
#                       Sector           Language  \
# 0          Business Services
# 1     Information Technology   python, java, c#
# 2     Information Technology       python, java
# 3                    Finance
# 4                  Insurance             python
# ...                      ...                ...
# 2523  Information Technology               java
# 2524       Business Services                c++
# 2525  Information Technology  python, c++, java
# 2526                     NaN       python, java
# 2527       Business Services               java
#
#                                 DS_ML                    Education  \
# 0                       data analysis             master, bachelor
# 1                 stat, deep learning             master, bachelor
# 2                                stat             master, bachelor
# 3                                                 master, bachelor
# 4                                                 master, bachelor
# ...                               ...                          ...
# 2523                                                      bachelor
# 2524                    data analysis                       master
# 2525  machine learning, deep learning             master, bachelor
# 2526                    data analysis  master, bachelor, doctorate
# 2527                                                      bachelor
#
#                                    Other skills
# 0      sql , nosql, sas, tableau, communication
# 1                sql , nosql, tableau, power bi
# 2
# 3                                 communication
# 4                          excel, communication
# ...                                         ...
# 2523                                       sql
# 2524
# 2525            algorithm, excel, communication
# 2526          sql , nosql, excel, communication
# 2527                                       sql
#
# [2409 rows x 13 columns]

# %% [markdown]
# ** Thử tìm các job về Software ở bang CA dựa vào các tiêu chí cụ thể**
#
# Đưa tất cả các tiêu chí vào 1 series để dễ quản lý, trong đó location có thể chọn nhập state hoặc thành phố hoặc cả hai. Mỗi dòng là 1 tiêu chí cho 1 cột. Ta có các tiêu chí như tên công việc, nơi làm việc, các ngôn ngữ lập trình, các kỹ năng cần thiết, bằng cấp và mức lương mình muốn.

# %%
quality = {'job': 'Data Engineer', 'location':'NY', 'Language': ['python','.net'], 'DS_ML': ['machine learning', 'deep learning'], 'Education': ['bachelor'], 'Other skills': ['sql','excel'], 'salary': 150}
Quality = pd.Series(data=quality,index=quality.keys())
Quality
# Out:
# job                                 Data Engineer
# location                                       NY
# Language                           [python, .net]
# DS_ML           [machine learning, deep learning]
# Education                              [bachelor]
# Other skills                         [sql, excel]
# salary                                        150
# dtype: object

# %%
filtering = find_jobs[(find_jobs['Job Title'].str.contains(Quality[0])) & (find_jobs['Location State'].str.contains(Quality[1]))]
for i in range(2,len(Quality)-1):
    filtering = pd.concat([filtering[filtering[Quality.index[i]].str.contains(j)] for j in Quality[i]],ignore_index=True)
filtering
# Out:
#                Job Title  Salary Lower  Salary Upper  Rating  \
# 0   Senior Data Engineer            80           150     3.0
# 1          Data Engineer            80           150     3.3
# 2   Senior Data Engineer            80           150     3.3
# 3          Data Engineer            80           150     3.7
# 4          Data Engineer            80           150     4.9
# ..                   ...           ...           ...     ...
# 64         Data Engineer            57            75     3.9
# 65         Data Engineer           105           121     5.0
# 66         Data Engineer           105           121     4.5
# 67         Data Engineer           105           121     3.9
# 68         Data Engineer           105           121     3.8
#
#                        Company Name Location State Location City  Size  \
# 0                Affinity Solutions             NY      New York   2.0
# 1                     PA Consulting             NY      New York   5.0
# 2                             Aetna             NY      New York   7.0
# 3                           PepsiCo             NY      New York   7.0
# 4                          Freestar             NY      New York   1.0
# ..                              ...            ...           ...   ...
# 64         Memorial Sloan-Kettering             NY      New York   7.0
# 65          Quantum Search Partners             NY      New York   1.0
# 66  Global Atlantic Financial Group             NY      New York   5.0
# 67              Madison Logic, Inc.             NY      New York   2.0
# 68                          Spotify             NY      New York   5.0
#
#                     Sector                             Language  \
# 0        Business Services                               python
# 1        Business Services  python, c++, java, javascript, html
# 2                Insurance                         python, java
# 3            Manufacturing                         python, java
# 4        Business Services                         python, java
# ..                     ...                                  ...
# 64             Health Care                               python
# 65                     NaN                               python
# 66               Insurance                         python, java
# 67       Business Services                               python
# 68  Information Technology                         python, java
#
#                                     DS_ML         Education  \
# 0                        machine learning  master, bachelor
# 1       machine learning, stat,  ai , nlp  master, bachelor
# 2                  machine learning, stat  master, bachelor
# 3   machine learning, stat, deep learning  master, bachelor
# 4   machine learning, stat, data analysis  master, bachelor
# ..                                    ...               ...
# 64                    stat, deep learning  master, bachelor
# 65        machine learning, deep learning  master, bachelor
# 66                    stat, deep learning  master, bachelor
# 67  machine learning, stat, deep learning  master, bachelor
# 68                          deep learning  master, bachelor
#
#                             Other skills
# 0                         nosql, tableau
# 1              nosql, algorithm, tableau
# 2        nosql, algorithm, communication
# 3                       nosql, algorithm
# 4    sql , excel, tableau, communication
# ..                                   ...
# 64                sql , algorithm, excel
# 65     sql , nosql, excel, communication
# 66            sql , excel, communication
# 67                           sql , excel
# 68         excel, tableau, communication
#
# [69 rows x 13 columns]

# %%
list_of_index = []

for i in range(0, len(filtering)):
    if Quality[6] in range(filtering["Salary Lower"][i],filtering["Salary Upper"][i]+1):
        list_of_index.append(i)
filtering.iloc[list_of_index]
# Out:
#                Job Title  Salary Lower  Salary Upper  Rating  \
# 0   Senior Data Engineer            80           150     3.0
# 1          Data Engineer            80           150     3.3
# 2   Senior Data Engineer            80           150     3.3
# 3          Data Engineer            80           150     3.7
# 4          Data Engineer            80           150     4.9
# 8   Senior Data Engineer            85           154     3.0
# 9          Data Engineer            85           154     3.8
# 10         Data Engineer            85           154     3.8
# 11  Senior Data Engineer            85           154     3.3
# 28  Senior Data Engineer            80           150     3.4
# 29         Data Engineer            80           150     3.7
# 32         Data Engineer            85           154     3.8
# 33         Data Engineer            85           154     3.9
# 34         Data Engineer            85           154     4.3
# 35         Data Engineer            85           154     3.6
# 48         Data Engineer            80           150     4.9
# 49         Data Engineer            80           150     2.5
# 60         Data Engineer            85           154     3.9
# 61         Data Engineer            85           154     4.3
# 62         Data Engineer            85           154     3.6
#
#               Company Name Location State Location City  Size  \
# 0       Affinity Solutions             NY      New York   2.0
# 1            PA Consulting             NY      New York   5.0
# 2                    Aetna             NY      New York   7.0
# 3                  PepsiCo             NY      New York   7.0
# 4                 Freestar             NY      New York   1.0
# 8       Affinity Solutions             NY      New York   2.0
# 9                Bloomberg             NY      New York   7.0
# 10                 Citadel             NY      New York   5.0
# 11                   Aetna             NY      New York   7.0
# 28  Enterprise Integration             NY      New York   2.0
# 29                 PepsiCo             NY      New York   7.0
# 32               Bloomberg             NY      New York   7.0
# 33              Millennium             NY      New York   5.0
# 34                BrainPOP             NY      New York   2.0
# 35                  Nasdaq             NY      New York   5.0
# 48                Freestar             NY      New York   1.0
# 49              FourSquare             NY      New York   2.0
# 60              Millennium             NY      New York   5.0
# 61                BrainPOP             NY      New York   2.0
# 62                  Nasdaq             NY      New York   5.0
#
#                     Sector                             Language  \
# 0        Business Services                               python
# 1        Business Services  python, c++, java, javascript, html
# 2                Insurance                         python, java
# 3            Manufacturing                         python, java
# 4        Business Services                         python, java
# 8        Business Services                               python
# 9   Information Technology                               python
# 10                     NaN             python, java, javascript
# 11               Insurance                         python, java
# 28  Information Technology                     python, java, c#
# 29           Manufacturing                         python, java
# 32  Information Technology                               python
# 33                 Finance                    python, c++, java
# 34               Education                         python, java
# 35                 Finance                         python, java
# 48       Business Services                         python, java
# 49  Information Technology                     python, java, c#
# 60                 Finance                    python, c++, java
# 61               Education                         python, java
# 62                 Finance                         python, java
#
#                                                 DS_ML         Education  \
# 0                                    machine learning  master, bachelor
# 1                   machine learning, stat,  ai , nlp  master, bachelor
# 2                              machine learning, stat  master, bachelor
# 3               machine learning, stat, deep learning  master, bachelor
# 4               machine learning, stat, data analysis  master, bachelor
# 8                                    machine learning  master, bachelor
# 9          machine learning, stat, nlp, deep learning  master, bachelor
# 10                             machine learning, stat  master, bachelor
# 11                             machine learning, stat  master, bachelor
# 28                                stat, deep learning  master, bachelor
# 29              machine learning, stat, deep learning  master, bachelor
# 32         machine learning, stat, nlp, deep learning  master, bachelor
# 33  stat, numpy, pandas, data analysis, deep learning  master, bachelor
# 34                                stat, deep learning  master, bachelor
# 35     regression, stat, data analysis, deep learning  master, bachelor
# 48              machine learning, stat, data analysis  master, bachelor
# 49                             machine learning, stat  master, bachelor
# 60  stat, numpy, pandas, data analysis, deep learning  master, bachelor
# 61                                stat, deep learning  master, bachelor
# 62     regression, stat, data analysis, deep learning  master, bachelor
#
#                             Other skills
# 0                         nosql, tableau
# 1              nosql, algorithm, tableau
# 2        nosql, algorithm, communication
# 3                       nosql, algorithm
# 4    sql , excel, tableau, communication
# 8                         nosql, tableau
# 9                            sql , nosql
# 10                  nosql, communication
# 11       nosql, algorithm, communication
# 28        sql , nosql, tableau, power bi
# 29                      nosql, algorithm
# 32                           sql , nosql
# 33            sql , excel, communication
# 34                sql , algorithm, excel
# 35            sql , excel, communication
# 48   sql , excel, tableau, communication
# 49                  excel, communication
# 60            sql , excel, communication
# 61                sql , algorithm, excel
# 62            sql , excel, communication
